# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## EPA steel data: GHG emissions

# %%
epa_df = pd.read_excel('./epa_flight_iron_and_steel_2022_emissions.xls', skiprows=5)
epa_df['FACILITY NAME'] = epa_df['FACILITY NAME'].apply(lambda x: x.upper().replace('U.S.','US'))
epa_df['Latitude rounded'] = epa_df['LATITUDE'].apply(lambda x: np.round(x,1))
epa_df['Longitude rounded'] = epa_df['LONGITUDE'].apply(lambda x: np.round(x,1))
epa_df.head(5)
# Out:
#    REPORTING YEAR              FACILITY NAME  GHGRP ID       REPORTED ADDRESS  \
# 0            2022                   ABC COKE   1004511    ONE RAILROAD AVENUE
# 1            2022        ALTON STEEL COMPANY   1003268             #5 CUT ST.
# 2            2022  ARKANSAS STEEL ASSOCIATES   1005801     2803 VAN DYKE ROAD
# 3            2022         BRACKENRIDGE PLANT   1005003         100 RIVER ROAD
# 4            2022        BIG RIVER STEEL LLC   1012997  2027 E. State Hwy.198
#
#     LATITUDE  LONGITUDE     CITY NAME       COUNTY NAME STATE  ZIP CODE  \
# 0  33.580769 -86.781281       TARRANT  JEFFERSON COUNTY    AL     35217
# 1  38.883210 -90.145030         ALTON    MADISON COUNTY    IL     62002
# 2  35.648518 -91.244662       NEWPORT    JACKSON COUNTY    AR     72112
# 3  40.608100 -79.729100  BRACKENRIDGE  ALLEGHENY COUNTY    PA     15014
# 4  35.696993 -90.037320       Osceola               NaN    AR     72370
#
#                        PARENT COMPANIES  GHG QUANTITY (METRIC TONS CO2e)  \
# 0                DRUMMOND CO INC (100%)                           181006
# 1                ALTON STEEL INC (100%)                            22147
# 2  ARKANSAS STEEL ASSOCIATES LLC (100%)                            56470
# 3     ALLEGHENY TECHNOLOGIES INC (100%)                           120167
# 4  BRS INTERMEDIATE HOLDINGS LLC (100%)                           524036
#
#   SUBPARTS  Latitude rounded  Longitude rounded
# 0      C,Q              33.6              -86.8
# 1      C,Q              38.9              -90.1
# 2      C,Q              35.6              -91.2
# 3      C,Q              40.6              -79.7
# 4      C,Q              35.7              -90.0

# %% [markdown]
# ## Global tracker data: Main production process mapping, select only BF/BOF

# %%
global_tracker_df = pd.read_excel('./Global-Steel-Plant-Tracker-2023-03-2.xlsx', sheet_name='Steel Plants')

# %%
# Select only U.S. plants and BF/BOF ones in global tracker data
global_tracker_df = global_tracker_df[global_tracker_df['Country'] == 'United States']
global_tracker_df['FACILITY NAME'] = global_tracker_df['Plant name (English)'].apply(lambda x: x.upper().replace('U.S.','US'))
global_tracker_df = global_tracker_df[(global_tracker_df['Main production process'] == 'integrated (BF)') | (global_tracker_df['Main production process'] == 'oxygen')]
print(len(global_tracker_df))
global_tracker_df
# US Steel Great Lakes closed down in 2020
# Out:
# 10
#       Plant ID                         Plant name (English)  \
# 1370  SUS00051                U.S. Steel Granite City Works
# 1372  SUS00005       Cleveland-Cliffs Riverdale steel plant
# 1374  SUS00006    Cleveland-Cliffs Burns Harbor steel plant
# 1378  SUS00009  Cleveland-Cliffs Indiana Harbor steel plant
# 1379  SUS00049                        U.S. Steel Gary Works
# 1388  SUS00003        Cleveland-Cliffs Dearborn steel plant
# 1389  SUS00050                 U.S. Steel Great Lakes Works
# 1399  SUS00010       Cleveland-Cliffs Cleveland steel plant
# 1405  SUS00004      Cleveland-Cliffs Middletown steel plant
# 1410  SUS00047               U.S. Steel Edgar Thomson Plant
#
#      Plant name (other language)  \
# 1370                         NaN
# 1372                         NaN
# 1374                         NaN
# 1378                         NaN
# 1379                         NaN
# 1388                         NaN
# 1389                         NaN
# 1399                         NaN
# 1405                         NaN
# 1410                         NaN
#
#                             Other plant names (English)  \
# 1370                            U.S. Steel Granite City
# 1372  Riverdale Works, ArcelorMittal Riverdale steel...
# 1374  Burns Harbor, ArcelorMittal Burns Harbor steel...
# 1378  Indiana Harbor, ArcelorMittal Indiana Harbor s...
# 1379                                    U.S. Steel Gary
# 1388                  Dearborn Works, AK Steel Dearborn
# 1389           U.S. Steel Ecorse, U.S. Steel Zug Island
# 1399  Cleveland Works, ArcelorMittal Cleveland steel...
# 1405              Middletown Works, AK Steel Middletown
# 1410  Mon Valley Works Edgar Thomson, U.S. Steel Bra...
#
#      Other plant names (other language) SOE status SOE state department  \
# 1370                                NaN        NaN                  NaN
# 1372                                NaN        NaN                  NaN
# 1374                                NaN        NaN                  NaN
# 1378                                NaN        NaN                  NaN
# 1379                                NaN        NaN                  NaN
# 1388                                NaN        NaN                  NaN
# 1389                                NaN        NaN                  NaN
# 1399                                NaN        NaN                  NaN
# 1405                                NaN        NaN                  NaN
# 1410                                NaN        NaN                  NaN
#
#                      Parent [formula] Parent PermID [formula]  \
# 1370  United States Steel Corp [100%]       4295903049 [100%]
# 1372      Cleveland-Cliffs Inc [100%]       4295903753 [100%]
# 1374      Cleveland-Cliffs Inc [100%]       4295903753 [100%]
# 1378      Cleveland-Cliffs Inc [100%]       4295903753 [100%]
# 1379  United States Steel Corp [100%]       4295903049 [100%]
# 1388      Cleveland-Cliffs Inc [100%]       4295903753 [100%]
# 1389  United States Steel Corp [100%]       4295903049 [100%]
# 1399      Cleveland-Cliffs Inc [100%]       4295903753 [100%]
# 1405      Cleveland-Cliffs Inc [100%]       4295903753 [100%]
# 1410  United States Steel Corp [100%]       4295903049 [100%]
#
#                          Owner  ... ISO 14001 ISO 50001  \
# 1370  United States Steel Corp  ...      2021       NaN
# 1372      Cleveland-Cliffs Inc  ...      2020       NaN
# 1374      Cleveland-Cliffs Inc  ...      2021       NaN
# 1378      Cleveland-Cliffs Inc  ...      2021       NaN
# 1379  United States Steel Corp  ...       NaN       NaN
# 1388      Cleveland-Cliffs Inc  ...      2018       NaN
# 1389  United States Steel Corp  ...      2021       NaN
# 1399      Cleveland-Cliffs Inc  ...      2020       NaN
# 1405      Cleveland-Cliffs Inc  ...      2022       NaN
# 1410  United States Steel Corp  ...      2019       NaN
#
#      ResponsibleSteel Certification Main production process  \
# 1370                            NaT         integrated (BF)
# 1372                            NaT                  oxygen
# 1374                            NaT         integrated (BF)
# 1378                            NaT         integrated (BF)
# 1379                            NaT         integrated (BF)
# 1388                            NaT         integrated (BF)
# 1389                            NaT         integrated (BF)
# 1399                            NaT         integrated (BF)
# 1405                            NaT         integrated (BF)
# 1410                            NaT         integrated (BF)
#
#      Main production equipment  \
# 1370                   BF, BOF
# 1372                       BOF
# 1374                   BF, BOF
# 1378              BF, BOF, EAF
# 1379                   BF, BOF
# 1388                   BF, BOF
# 1389                   BF, BOF
# 1399                   BF, BOF
# 1405                   BF, BOF
# 1410                   BF, BOF
#
#                           Detailed production equipment Power source  \
# 1370                              2 BOF (began in 1967)          NaN
# 1372  sinter plant; 2 BOF (57m3 each, began in 1959,...          NaN
# 1374  2 coking plants (began in 1983 and 1994, 82 ov...          NaN
# 1378  2 sinter plants; 6 BOF; 1 EAF (began in 1970, ...          NaN
# 1379           3 BOF (began in 1965, 1973, and unknown)          NaN
# 1388                              2 BOF (began in 1963)          NaN
# 1389          2 BOF (began in 1970, idled in Jan. 2020)          NaN
# 1399  coking plant; 4 BOF (2 BOF began in 1961, 2 BO...          NaN
# 1405  coking plant (began in 1953, 76 ovens, 20.67m3...          NaN
# 1410                              2 BOF (began in 1972)          NaN
#
#      Iron ore source                                    Met coal source  \
# 1370             NaN                                                NaN
# 1372             NaN                                                NaN
# 1374             NaN                                                NaN
# 1378             NaN                                                NaN
# 1379             NaN                                                NaN
# 1388             NaN                                                NaN
# 1389             NaN                                                NaN
# 1399             NaN  Coke supplied from Cleveland-Cliffs Warren, Oh...
# 1405             NaN                                                NaN
# 1410             NaN  Coke supplied from Mon Valley Works Clairton P...
#
#                                     FACILITY NAME
# 1370                  US STEEL GRANITE CITY WORKS
# 1372       CLEVELAND-CLIFFS RIVERDALE STEEL PLANT
# 1374    CLEVELAND-CLIFFS BURNS HARBOR STEEL PLANT
# 1378  CLEVELAND-CLIFFS INDIANA HARBOR STEEL PLANT
# 1379                          US STEEL GARY WORKS
# 1388        CLEVELAND-CLIFFS DEARBORN STEEL PLANT
# 1389                   US STEEL GREAT LAKES WORKS
# 1399       CLEVELAND-CLIFFS CLEVELAND STEEL PLANT
# 1405      CLEVELAND-CLIFFS MIDDLETOWN STEEL PLANT
# 1410                 US STEEL EDGAR THOMSON PLANT
#
# [10 rows x 52 columns]

# %% [markdown]
# ## Merge EPA and Global tracker data on latitude, longitude and plant name

# %%
global_tracker_df['Latitude rounded'] = global_tracker_df['Coordinates'].apply(lambda x:np.round(float(str(x).split(',')[0]),1))
global_tracker_df['Longitude rounded'] = global_tracker_df['Coordinates'].apply(lambda x:np.round(float(str(x).split(',')[1]),1))
global_tracker_df['Name 2 letters'] = global_tracker_df['FACILITY NAME'].apply(lambda x:x[:2])
epa_df['Name 2 letters'] = epa_df['FACILITY NAME'].apply(lambda x:x[:2])

# %%
# Merge 
merged  = pd.merge(global_tracker_df, epa_df, on=['Latitude rounded', 'Longitude rounded','Name 2 letters'])

# %%
# Get the production process capacity
merged['Steel production capacity (ttpa)'] = (
  np.where(
    merged['Main production process'] == 'oxygen',
    merged['Nominal BOF steel capacity (ttpa)'],
    np.where(
      merged['Main production process'] =='integrated (BF)',
      merged['Nominal BF capacity (ttpa)'], None
    )
))
merged
# Out:
#    Plant ID                         Plant name (English)  \
# 0  SUS00051                U.S. Steel Granite City Works
# 1  SUS00005       Cleveland-Cliffs Riverdale steel plant
# 2  SUS00006    Cleveland-Cliffs Burns Harbor steel plant
# 3  SUS00009  Cleveland-Cliffs Indiana Harbor steel plant
# 4  SUS00049                        U.S. Steel Gary Works
# 5  SUS00003        Cleveland-Cliffs Dearborn steel plant
# 6  SUS00010       Cleveland-Cliffs Cleveland steel plant
# 7  SUS00004      Cleveland-Cliffs Middletown steel plant
# 8  SUS00047               U.S. Steel Edgar Thomson Plant
#
#   Plant name (other language)  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
#
#                          Other plant names (English)  \
# 0                            U.S. Steel Granite City
# 1  Riverdale Works, ArcelorMittal Riverdale steel...
# 2  Burns Harbor, ArcelorMittal Burns Harbor steel...
# 3  Indiana Harbor, ArcelorMittal Indiana Harbor s...
# 4                                    U.S. Steel Gary
# 5                  Dearborn Works, AK Steel Dearborn
# 6  Cleveland Works, ArcelorMittal Cleveland steel...
# 7              Middletown Works, AK Steel Middletown
# 8  Mon Valley Works Edgar Thomson, U.S. Steel Bra...
#
#   Other plant names (other language) SOE status SOE state department  \
# 0                                NaN        NaN                  NaN
# 1                                NaN        NaN                  NaN
# 2                                NaN        NaN                  NaN
# 3                                NaN        NaN                  NaN
# 4                                NaN        NaN                  NaN
# 5                                NaN        NaN                  NaN
# 6                                NaN        NaN                  NaN
# 7                                NaN        NaN                  NaN
# 8                                NaN        NaN                  NaN
#
#                   Parent [formula] Parent PermID [formula]  \
# 0  United States Steel Corp [100%]       4295903049 [100%]
# 1      Cleveland-Cliffs Inc [100%]       4295903753 [100%]
# 2      Cleveland-Cliffs Inc [100%]       4295903753 [100%]
# 3      Cleveland-Cliffs Inc [100%]       4295903753 [100%]
# 4  United States Steel Corp [100%]       4295903049 [100%]
# 5      Cleveland-Cliffs Inc [100%]       4295903753 [100%]
# 6      Cleveland-Cliffs Inc [100%]       4295903753 [100%]
# 7      Cleveland-Cliffs Inc [100%]       4295903753 [100%]
# 8  United States Steel Corp [100%]       4295903049 [100%]
#
#                       Owner  ...   LATITUDE  LONGITUDE     CITY NAME  \
# 0  United States Steel Corp  ...  38.695400 -90.136700  GRANITE CITY
# 1      Cleveland-Cliffs Inc  ...  41.656474 -87.625847     RIVERDALE
# 2      Cleveland-Cliffs Inc  ...  41.634000 -87.131000  BURNS HARBOR
# 3      Cleveland-Cliffs Inc  ...  41.680000 -87.426400  EAST CHICAGO
# 4  United States Steel Corp  ...  41.613300 -87.328100          GARY
# 5      Cleveland-Cliffs Inc  ...  42.301742 -83.162934      DEARBORN
# 6      Cleveland-Cliffs Inc  ...  41.473900 -81.672800     CLEVELAND
# 7      Cleveland-Cliffs Inc  ...  39.496800 -84.390100    MIDDLETOWN
# 8  United States Steel Corp  ...  40.392500 -79.856400      Braddock
#
#       COUNTY NAME STATE ZIP CODE             PARENT COMPANIES  \
# 0  MADISON COUNTY    IL    62040         US STEEL CORP (100%)
# 1     COOK COUNTY    IL    60827  CLEVELAND-CLIFFS INC (100%)
# 2   PORTER COUNTY    IN    46304  CLEVELAND-CLIFFS INC (100%)
# 3            Lake    IN    46312  CLEVELAND-CLIFFS INC (100%)
# 4            Lake    IN    46402         US STEEL CORP (100%)
# 5    WAYNE COUNTY    MI    48120  CLEVELAND-CLIFFS INC (100%)
# 6        Cuyahoga    OH    44105  CLEVELAND-CLIFFS INC (100%)
# 7          Butler    OH    45043  CLEVELAND-CLIFFS INC (100%)
# 8       Allegheny    PA    15104         US STEEL CORP (100%)
#
#   GHG QUANTITY (METRIC TONS CO2e) SUBPARTS Steel production capacity (ttpa)
# 0                         1932947   C,Q,TT                             2540
# 1                          134985      C,Q                             1000
# 2                         6839238      C,Q                             3635
# 3                         5434569    C,Q,S                             5236
# 4                        10300727   C,Q,TT                             6622
# 5                         1015576      C,Q                             2500
# 6                         2942469      C,Q                             2810
# 7                         3227354      C,Q                             2090
# 8                         2995635      C,Q                             2078
#
# [9 rows x 69 columns]

# %%
# Check matching between the two dataset
merged = merged[['Plant name (English)', 'FACILITY NAME_x', 'FACILITY NAME_y', 'Coordinates', 'LATITUDE', 'LONGITUDE', 
                 'Location address', 'REPORTED ADDRESS', 'CITY NAME', 'COUNTY NAME', 'STATE', 'Subnational unit (province/state)','ZIP CODE',
                 'Status','Main production process', 'Main production equipment','GHG QUANTITY (METRIC TONS CO2e)','Steel production capacity (ttpa)']]
merged
# Out:
#                           Plant name (English)  \
# 0                U.S. Steel Granite City Works
# 1       Cleveland-Cliffs Riverdale steel plant
# 2    Cleveland-Cliffs Burns Harbor steel plant
# 3  Cleveland-Cliffs Indiana Harbor steel plant
# 4                        U.S. Steel Gary Works
# 5        Cleveland-Cliffs Dearborn steel plant
# 6       Cleveland-Cliffs Cleveland steel plant
# 7      Cleveland-Cliffs Middletown steel plant
# 8               U.S. Steel Edgar Thomson Plant
#
#                                FACILITY NAME_x  \
# 0                  US STEEL GRANITE CITY WORKS
# 1       CLEVELAND-CLIFFS RIVERDALE STEEL PLANT
# 2    CLEVELAND-CLIFFS BURNS HARBOR STEEL PLANT
# 3  CLEVELAND-CLIFFS INDIANA HARBOR STEEL PLANT
# 4                          US STEEL GARY WORKS
# 5        CLEVELAND-CLIFFS DEARBORN STEEL PLANT
# 6       CLEVELAND-CLIFFS CLEVELAND STEEL PLANT
# 7      CLEVELAND-CLIFFS MIDDLETOWN STEEL PLANT
# 8                 US STEEL EDGAR THOMSON PLANT
#
#                                      FACILITY NAME_y            Coordinates  \
# 0                            US STEEL - GRANITE CITY  38.695049, -90.136073
# 1                     CLEVELAND-CLIFFS RIVERDALE LLC  41.657321, -87.625702
# 2                  CLEVELAND-CLIFFS BURNS HARBOR LLC  41.631221, -87.143846
# 3                         CLEVELAND-CLIFFS STEEL LLC  41.669553, -87.438429
# 4                         US STEEL CORP - GARY WORKS  41.620799, -87.348266
# 5  CLEVELAND-CLIFFS STEEL CORPORATION DEARBORN WORKS  42.308171, -83.161353
# 6               CLEVELAND-CLIFFS CLEVELAND WORKS LLC  41.464041, -81.676499
# 7  CLEVELAND-CLIFFS STEEL CORPORATION - MIDDLETOW...  39.488589, -84.386197
# 8                           US STEEL (EDGAR THOMSON)  40.395140, -79.859645
#
#     LATITUDE  LONGITUDE                                   Location address  \
# 0  38.695400 -90.136700  Granite City Works, 1951 State Street, Granite...
# 1  41.656474 -87.625847  13500 Perry Ave, Riverdale, IL 60827, United S...
# 2  41.634000 -87.131000  250 W. U.S. Highway 12, Burns Harbor, IN 46304...
# 3  41.680000 -87.426400  3210 Watling St., East Chicago, IN 46312, Unit...
# 4  41.613300 -87.328100  Gary Works, One North Broadway, Gary, Indiana ...
# 5  42.301742 -83.162934  14661 Rotunda Drive, P.O. Box 1699, Dearborn, ...
# 6  41.473900 -81.672800  3060 Eggers Road, Cleveland, OH 44105, United ...
# 7  39.496800 -84.390100  1801 Crawford St., Middletown, OH 45043, Unite...
# 8  40.392500 -79.856400  Mon Valley Works, Edgar Thomson Plant, 13th St...
#
#                   REPORTED ADDRESS     CITY NAME     COUNTY NAME STATE  \
# 0                    1951 STATE ST  GRANITE CITY  MADISON COUNTY    IL
# 1                13500 S PERRY AVE     RIVERDALE     COOK COUNTY    IL
# 2                      250 W US 12  BURNS HARBOR   PORTER COUNTY    IN
# 3                  3210 WATLING ST  EAST CHICAGO            Lake    IN
# 4                 1 NORTH BROADWAY          GARY            Lake    IN
# 5                   4001 MILLER RD      DEARBORN    WAYNE COUNTY    MI
# 6               3060 EGGERS AVENUE     CLEVELAND        Cuyahoga    OH
# 7             1801 CRAWFORD STREET    MIDDLETOWN          Butler    OH
# 8  13th Street and Braddock Avenue      Braddock       Allegheny    PA
#
#   Subnational unit (province/state)  ZIP CODE     Status  \
# 0                          Illinois     62040  operating
# 1                          Illinois     60827  operating
# 2                           Indiana     46304  operating
# 3                           Indiana     46312  operating
# 4                           Indiana     46402  operating
# 5                          Michigan     48120  operating
# 6                              Ohio     44105  operating
# 7                              Ohio     45043  operating
# 8                      Pennsylvania     15104  operating
#
#   Main production process Main production equipment  \
# 0         integrated (BF)                   BF, BOF
# 1                  oxygen                       BOF
# 2         integrated (BF)                   BF, BOF
# 3         integrated (BF)              BF, BOF, EAF
# 4         integrated (BF)                   BF, BOF
# 5         integrated (BF)                   BF, BOF
# 6         integrated (BF)                   BF, BOF
# 7         integrated (BF)                   BF, BOF
# 8         integrated (BF)                   BF, BOF
#
#    GHG QUANTITY (METRIC TONS CO2e) Steel production capacity (ttpa)
# 0                          1932947                             2540
# 1                           134985                             1000
# 2                          6839238                             3635
# 3                          5434569                             5236
# 4                         10300727                             6622
# 5                          1015576                             2500
# 6                          2942469                             2810
# 7                          3227354                             2090
# 8                          2995635                             2078

# %%
# Select relevant columns for final dataset
clean_df = merged[['Plant name (English)', 'Coordinates', 'REPORTED ADDRESS', 'CITY NAME', 'COUNTY NAME', 'ZIP CODE',
                    'Status', 'Main production process', 'GHG QUANTITY (METRIC TONS CO2e)', 
                   'Steel production capacity (ttpa)']]

# %% [markdown]
# ## Calculation of equivalent hydrogen demand

# %%
hydrogen_rate = 67.095 #kg-H2/ton_DRI cf research notes
ratio_steel_dri = 0.9311 #t_steel/t_dri
clean_df['Hydrogen demand (kg/day)'] = clean_df['Steel production capacity (ttpa)']*1e3*hydrogen_rate/(365*ratio_steel_dri)
# Out:
# C:\Users\mgarrou\AppData\Local\Temp\ipykernel_18476\1189824766.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['Hydrogen demand (kg/day)'] = clean_df['Steel production capacity (ttpa)']*1e3*hydrogen_rate/(365*ratio_steel_dri)

# %% [markdown]
# ## Calculation of electricity demand from auxiliary components

# %%
aux_elec_demand_rate = 0.1025 #MWhe/ton-DRI cf research notes
eaf_elec_demand_rate = 0.461 #MWhe/tsteel cf research notes 
clean_df['Electricity demand (MWe)'] = clean_df['Steel production capacity (ttpa)']*1e3*(eaf_elec_demand_rate + aux_elec_demand_rate/ratio_steel_dri)/(365*24)
# Out:
# C:\Users\mgarrou\AppData\Local\Temp\ipykernel_18476\422874132.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['Electricity demand (MWe)'] = clean_df['Steel production capacity (ttpa)']*1e3*(eaf_elec_demand_rate + aux_elec_demand_rate/ratio_steel_dri)/(365*24)

# %% [markdown]
# ## Save clean results for code use

# %%
clean_df.rename(columns={'Plant name (English)':'Plant'}, inplace=True)
clean_df.to_excel('../h2_demand_bfbof_steel_us_2022.xlsx', sheet_name='processed', index=False)
# Out:
# C:\Users\mgarrou\AppData\Local\Temp\ipykernel_18476\2663812924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.rename(columns={'Plant name (English)':'Plant'}, inplace=True)
